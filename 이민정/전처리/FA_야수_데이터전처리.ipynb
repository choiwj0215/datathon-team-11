# %%
import pandas as pd

# %%
df = pd.read_csv('KBO FA 야수 [2013-2024]_최종.csv의 사본.csv')
df1 = pd.read_csv('야수 wRC+.csv의 사본.csv')

# %%
df.columns
# Out:
# Index(['FA년도', '구단명', '선수명', '포지션', '투', '타', '인정년수', '구분', 'FA등급', '플레이년도',
#        'Age', 'G', 'PA', 'AB', 'R', 'H', '2B', '3B', 'HP', 'HR', 'RBI', 'SB',
#        'CS', 'BB', 'SO', 'GDP', 'SF', '수비_필딩 RAA', '수비_포지션 RAA', '전체수비 RAA',
#        'oWAR', 'dWAR', '연봉', '비고', '잔류 여부', 'FA 계약 연수', 'FA 계약 총액',
#        'TEAM RANK', 'TEAM G', 'TEAM PA', 'TEAM AB', 'TEAM R', 'TEAM H',
#        'TEAM 2B', 'TEAM 3B', 'TEAM HP', 'TEAM HR', 'TEAM RBI', 'TEAM SB',
#        'TEAM CS', 'TEAM BB', 'TEAM SO', 'TEAM GDP', 'TEAM SF',
#        'TEAM 수비_필딩 RAA', 'TEAM 수비_포지션 RAA', 'TEAM 전체수비 RAA', 'TEAM oWAR',
#        'TEAM dWAR', 'TEAM 연봉'],
#       dtype='object')

# %%
df1.columns
# Out:
# Index(['Name', 'Year', 'PA', 'wRC+'], dtype='object')

# %%
df
# Out:
#      FA년도 구단명  선수명 포지션   투   타  인정년수      구분 FA등급  플레이년도  ...  TEAM BB  \
# 0    2011  롯데  강민호   C  우투  우타   9.0      신규    A   2010  ...      NaN
# 1    2012  롯데  강민호   C  우투  우타   9.0      신규    A   2011  ...      NaN
# 2    2013  롯데  강민호   C  우투  우타   9.0      신규    A   2012  ...    375.0
# 3    2014  롯데  강민호   C  우투  우타   9.0      신규    A   2013  ...    503.0
# 4    2015  롯데  강민호   C  우투  우타   4.0  FA 1년차    A   2014  ...    534.0
# ..    ...  ..  ...  ..  ..  ..   ...     ...  ...    ...  ...      ...
# 645  2019  KT  황재균  3B  우투  우타   4.0     재자격    B   2018  ...    464.0
# 646  2020  KT  황재균  3B  우투  우타   4.0     재자격    B   2019  ...    475.0
# 647  2021  KT  황재균  3B  우투  우타   4.0     재자격    B   2020  ...    554.0
# 648  2022  KT  황재균  3B  우투  우타   4.0     재자격    B   2021  ...    645.0
# 649  2023  KT  황재균  3B  우투  우타   NaN  FA 1년차  NaN   2022  ...    519.0
#
#      TEAM SO  TEAM GDP  TEAM SF  TEAM 수비_필딩 RAA  TEAM 수비_포지션 RAA  \
# ...

# %%
df1.columns = ['선수명', '플레이년도','PA','wRC+']

# %%
df1 = df1.dropna()
# Out:
#       선수명   플레이년도     PA   wRC+
# 1     강민호  2005.0  230.0   56.5
# 2     강민호  2006.0  460.0   84.8
# 3     강민호  2007.0  474.0  110.5
# 4     강민호  2008.0  501.0  134.5
# 5     강민호  2009.0  301.0   91.0
# ...   ...     ...    ...    ...
# 1610  이용규  2021.0  547.0  119.5
# 1611  이용규  2022.0  326.0   66.9
# 1612  이용규  2023.0  178.0   70.2
# 1613  이용규  2024.0  227.0  136.7
# 1614  이용규  2025.0   28.0   52.3
#
# [1614 rows x 4 columns]

# %%
result = pd.merge(df, df1, how='left', on=['선수명','플레이년도'])
result
# Out:
#      FA년도 구단명  선수명 포지션   투   타  인정년수      구분 FA등급  플레이년도  ...  TEAM GDP  \
# 0    2011  롯데  강민호   C  우투  우타   9.0      신규    A   2010  ...       NaN
# 1    2012  롯데  강민호   C  우투  우타   9.0      신규    A   2011  ...       NaN
# 2    2013  롯데  강민호   C  우투  우타   9.0      신규    A   2012  ...      91.0
# 3    2014  롯데  강민호   C  우투  우타   9.0      신규    A   2013  ...      92.0
# 4    2015  롯데  강민호   C  우투  우타   4.0  FA 1년차    A   2014  ...      95.0
# ..    ...  ..  ...  ..  ..  ..   ...     ...  ...    ...  ...       ...
# 646  2019  KT  황재균  3B  우투  우타   4.0     재자격    B   2018  ...     103.0
# 647  2020  KT  황재균  3B  우투  우타   4.0     재자격    B   2019  ...     113.0
# 648  2021  KT  황재균  3B  우투  우타   4.0     재자격    B   2020  ...     104.0
# 649  2022  KT  황재균  3B  우투  우타   4.0     재자격    B   2021  ...     105.0
# 650  2023  KT  황재균  3B  우투  우타   NaN  FA 1년차  NaN   2022  ...     105.0
#
#      TEAM SF  TEAM 수비_필딩 RAA  TEAM 수비_포지션 RAA  TEAM 전체수비 RAA  TEAM oWAR  \
# ...

# %%
result.to_csv('FA_야수_데이터_통합.csv', index = False)
