# %%
import pandas as pd

# %%
df = pd.read_csv('야수_전처리_ver04.csv')
df1 = pd.read_excel('파크팩터.xlsx')
df1
# Out:
#      구단명  플레이년도  득점파크팩터  홈런파크팩터  장타파크팩터 구단지역
# 0     키움   2010     999    1128    1032   서울
# 1     키움   2011    1019    1128    1032   서울
# 2     키움   2012    1029    1128    1032   서울
# 3     키움   2013    1058    1128    1032   서울
# 4     키움   2014    1046    1123    1012   서울
# ..   ...    ...     ...     ...     ...  ...
# 147  SSG   2021    1027    1139     968   인천
# 148  SSG   2022    1034    1175     959   인천
# 149  SSG   2023    1025    1190     940   인천
# 150  SSG   2024    1037    1221     943   인천
# 151  SSG   2025    1010    1177     939   인천
#
# [152 rows x 6 columns]

# %%
merged_df = pd.merge(df, df1, how='left', on=['구단명', '플레이년도'])
merged_df
# Out:
#      FA년도 구단명        선수명 포지션   투   타      구분 FA등급  플레이년도  나이  ...  FA 계약 연수  \
# 0    2011  롯데  강민호(2011)   C  우투  우타      신규    A   2010  25  ...         0
# 1    2012  롯데  강민호(2011)   C  우투  우타      신규    A   2011  26  ...         0
# 2    2013  롯데  강민호(2011)   C  우투  우타      신규    A   2012  27  ...         0
# 3    2014  롯데  강민호(2011)   C  우투  우타      신규    A   2013  28  ...         4
# 4    2015  롯데  강민호(2015)   C  우투  우타  FA 1년차    A   2014  29  ...         0
# ..    ...  ..        ...  ..  ..  ..     ...  ...    ...  ..  ...       ...
# 662  2019  KT  황재균(2019)  3B  우투  우타  FA 1년차    B   2018  31  ...         0
# 663  2020  KT  황재균(2019)  3B  우투  우타     재자격    B   2019  32  ...         0
# 664  2021  KT  황재균(2019)  3B  우투  우타     재자격    B   2020  33  ...         0
# 665  2022  KT  황재균(2019)  3B  우투  우타     재자격    B   2021  34  ...         4
# 666  2023  KT  황재균(2023)  3B  우투  우타  FA 1년차    B   2022  35  ...         0
#
# ...

# %%
merged_df.to_csv('야수_전처리_ver05.csv', index = False)
