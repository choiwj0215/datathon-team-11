# %%
import pandas as pd

# %%
df = pd.read_csv('FA_야수_데이터_합치기.csv')

# %%
df.isna().sum()
# Out:
# FA년도          0
# 구단명           0
# 선수명           0
# 포지션          13
# 투             0
#              ..
# TEAM oWAR    67
# TEAM dWAR    67
# TEAM 연봉      67
# PA_y         13
# wRC+         13
# Length: 62, dtype: int64

# %%
pd.set_option('display.max_columns', None)
pd.reset_option('display.max_rows', None)

# %%
df = df[~df['구단명'].isin(['군 복무', '은퇴', '구단 징계', '부상 시즌 아웃'])]

# %%
df = df.reset_index()

# %%
df
# Out:
#      index  FA년도 구단명  선수명 포지션   투   타  인정년수      구분 FA등급  플레이년도   Age      G  \
# 0        0  2011  롯데  강민호   C  우투  우타   9.0      신규    A   2010  25.0  117.0
# 1        1  2012  롯데  강민호   C  우투  우타   9.0      신규    A   2011  26.0  124.0
# 2        2  2013  롯데  강민호   C  우투  우타   9.0      신규    A   2012  27.0  119.0
# 3        3  2014  롯데  강민호   C  우투  우타   9.0      신규    A   2013  28.0  105.0
# 4        4  2015  롯데  강민호   C  우투  우타   4.0  FA 1년차    A   2014  29.0   98.0
# ..     ...   ...  ..  ...  ..  ..  ..   ...     ...  ...    ...   ...    ...
# 632    646  2019  KT  황재균  3B  우투  우타   4.0     재자격    B   2018  31.0  142.0
# 633    647  2020  KT  황재균  3B  우투  우타   4.0     재자격    B   2019  32.0  124.0
# 634    648  2021  KT  황재균  3B  우투  우타   4.0     재자격    B   2020  33.0  134.0
# 635    649  2022  KT  황재균  3B  우투  우타   4.0     재자격    B   2021  34.0  117.0
# 636    650  2023  KT  황재균  3B  우투  우타   NaN  FA 1년차  NaN   2022  35.0  141.0
#
# ...

# %%
df.columns
# Out:
# Index(['index', 'FA년도', '구단명', '선수명', '포지션', '투', '타', '인정년수', '구분', 'FA등급',
#        '플레이년도', 'Age', 'G', 'PA_x', 'AB', 'R', 'H', '2B', '3B', 'HP', 'HR',
#        'RBI', 'SB', 'CS', 'BB', 'SO', 'GDP', 'SF', '수비_필딩 RAA', '수비_포지션 RAA',
#        '전체수비 RAA', 'oWAR', 'dWAR', '연봉', '비고', '잔류 여부', 'FA 계약 연수', 'FA 계약 총액',
#        'TEAM RANK', 'TEAM G', 'TEAM PA', 'TEAM AB', 'TEAM R', 'TEAM H',
#        'TEAM 2B', 'TEAM 3B', 'TEAM HP', 'TEAM HR', 'TEAM RBI', 'TEAM SB',
#        'TEAM CS', 'TEAM BB', 'TEAM SO', 'TEAM GDP', 'TEAM SF',
#        'TEAM 수비_필딩 RAA', 'TEAM 수비_포지션 RAA', 'TEAM 전체수비 RAA', 'TEAM oWAR',
#        'TEAM dWAR', 'TEAM 연봉', 'PA_y', 'wRC+'],
#       dtype='object')

# %%
df = df.drop(['index'],axis=1)

# %%
df.columns = ['FA년도', '구단명', '선수명', '포지션', '투', '타', '인정년수', '구분', 'FA등급', '플레이년도',
       '나이', '게임수', '타석수', '타수', '득점', '안타', '2루타', '3루타', '사구', '홈런', '타점', '도루성공',
       '도루실패', '볼넷', '삼진', '병살타', '희생플라이', '평균대비수비득점기여', '수비_포지션 RAA', '전체수비 RAA',
       '공격WAR', '수비WAR', '연봉', '비고', '잔류 여부', 'FA 계약 연수', 'FA 계약 총액',
       'TEAM 순위', 'TEAM 게임수', 'TEAM 타석수', 'TEAM 타수', 'TEAM 득점', 'TEAM 안타',
       'TEAM 2루타', 'TEAM 3루타', 'TEAM 사구', 'TEAM 홈런', 'TEAM 타점', 'TEAM 도루',
       'TEAM 도루실패', 'TEAM 볼넷', 'TEAM 삼진', 'TEAM 병살타', 'TEAM 희생플라이',
       'TEAM 평균대비수비득점기여', 'TEAM 수비_포지션 RAA', 'TEAM 전체수비 RAA', 'TEAM 공격WAR',
       'TEAM 수비WAR', 'TEAM 연봉', '타석수y', 'wRC+']

# %%
df
# Out:
#      FA년도 구단명  선수명 포지션   투   타  인정년수      구분 FA등급  플레이년도    나이    게임수    타석수  \
# 0    2011  롯데  강민호   C  우투  우타   9.0      신규    A   2010  25.0  117.0  465.0
# 1    2012  롯데  강민호   C  우투  우타   9.0      신규    A   2011  26.0  124.0  506.0
# 2    2013  롯데  강민호   C  우투  우타   9.0      신규    A   2012  27.0  119.0  454.0
# 3    2014  롯데  강민호   C  우투  우타   9.0      신규    A   2013  28.0  105.0  405.0
# 4    2015  롯데  강민호   C  우투  우타   4.0  FA 1년차    A   2014  29.0   98.0  360.0
# ..    ...  ..  ...  ..  ..  ..   ...     ...  ...    ...   ...    ...    ...
# 632  2019  KT  황재균  3B  우투  우타   4.0     재자격    B   2018  31.0  142.0  588.0
# 633  2020  KT  황재균  3B  우투  우타   4.0     재자격    B   2019  32.0  124.0  507.0
# 634  2021  KT  황재균  3B  우투  우타   4.0     재자격    B   2020  33.0  134.0  600.0
# 635  2022  KT  황재균  3B  우투  우타   4.0     재자격    B   2021  34.0  117.0  507.0
# 636  2023  KT  황재균  3B  우투  우타   NaN  FA 1년차  NaN   2022  35.0  141.0  581.0
#
# ...

# %%
a1 = df[['선수명','플레이년도','타석수','타석수y']]
pa = a1[a1['타석수'] != a1['타석수y']]
pa
# Out:
#      선수명  플레이년도    타석수   타석수y
# 416  이우민   2013  251.0  453.0
# 417  이우민   2014  103.0  418.0
# 418  이우민   2015  174.0  585.0
# 419  이우민   2016   98.0  530.0
# 420  이우민   2017  215.0  200.0
# 543  조인성   2014  185.0   31.0
# 544  조인성   2014  185.0  154.0
# 567  최재훈   2018  420.0  341.0

# %%
df.loc[543, '타석수'] = 31.0
df.loc[544, '타석수'] = 154.0
df.loc[567, '타석수'] = 341.0

# %%
df= df.drop(['타석수y'], axis = 1)

df
# Out:
#      FA년도 구단명  선수명 포지션   투   타  인정년수      구분 FA등급  플레이년도    나이    게임수    타석수  \
# 0    2011  롯데  강민호   C  우투  우타   9.0      신규    A   2010  25.0  117.0  465.0
# 1    2012  롯데  강민호   C  우투  우타   9.0      신규    A   2011  26.0  124.0  506.0
# 2    2013  롯데  강민호   C  우투  우타   9.0      신규    A   2012  27.0  119.0  454.0
# 3    2014  롯데  강민호   C  우투  우타   9.0      신규    A   2013  28.0  105.0  405.0
# 4    2015  롯데  강민호   C  우투  우타   4.0  FA 1년차    A   2014  29.0   98.0  360.0
# ..    ...  ..  ...  ..  ..  ..   ...     ...  ...    ...   ...    ...    ...
# 632  2019  KT  황재균  3B  우투  우타   4.0     재자격    B   2018  31.0  142.0  588.0
# 633  2020  KT  황재균  3B  우투  우타   4.0     재자격    B   2019  32.0  124.0  507.0
# 634  2021  KT  황재균  3B  우투  우타   4.0     재자격    B   2020  33.0  134.0  600.0
# 635  2022  KT  황재균  3B  우투  우타   4.0     재자격    B   2021  34.0  117.0  507.0
# 636  2023  KT  황재균  3B  우투  우타   NaN  FA 1년차  NaN   2022  35.0  141.0  581.0
#
# ...

# %%
df
# Out:
#      FA년도 구단명  선수명 포지션   투   타  인정년수      구분 FA등급  플레이년도    나이    게임수    타석수  \
# 0    2011  롯데  강민호   C  우투  우타   9.0      신규    A   2010  25.0  117.0  465.0
# 1    2012  롯데  강민호   C  우투  우타   9.0      신규    A   2011  26.0  124.0  506.0
# 2    2013  롯데  강민호   C  우투  우타   9.0      신규    A   2012  27.0  119.0  454.0
# 3    2014  롯데  강민호   C  우투  우타   9.0      신규    A   2013  28.0  105.0  405.0
# 4    2015  롯데  강민호   C  우투  우타   4.0  FA 1년차    A   2014  29.0   98.0  360.0
# ..    ...  ..  ...  ..  ..  ..   ...     ...  ...    ...   ...    ...    ...
# 632  2019  KT  황재균  3B  우투  우타   4.0     재자격    B   2018  31.0  142.0  588.0
# 633  2020  KT  황재균  3B  우투  우타   4.0     재자격    B   2019  32.0  124.0  507.0
# 634  2021  KT  황재균  3B  우투  우타   4.0     재자격    B   2020  33.0  134.0  600.0
# 635  2022  KT  황재균  3B  우투  우타   4.0     재자격    B   2021  34.0  117.0  507.0
# 636  2023  KT  황재균  3B  우투  우타   NaN  FA 1년차  NaN   2022  35.0  141.0  581.0
#
# ...

# %%
df.to_csv('FA_야수데이터.csv', index = False)
