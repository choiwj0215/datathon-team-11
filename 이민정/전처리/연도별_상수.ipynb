# %%
import pandas as pd

# %%
df = pd.read_csv('연도별 상수.csv의 사본.csv')

# %%
df.columns = [['연도','평균가중출루율','가중출루율_점수_보정값','볼넷가치','안타가치','2루타가치','3루타가치','홈런가치', '2루도루성공가치','3루도루성공가치',
        '2루도루실패가치','3루도루실패가치','유효타석당득점','승리당득점','FIP상황보정']]
# Out:
#       연도 평균가중출루율 가중출루율_점수_보정값   볼넷가치   안타가치  2루타가치  3루타가치   홈런가치 2루도루성공가치  \
# 0   1982   0.338        1.046  0.413  0.590  0.985  1.171  1.358    0.174
# 1   1983   0.323        1.129  0.393  0.561  0.941  1.160  1.379    0.167
# 2   1984   0.326        1.157  0.387  0.553  0.930  1.158  1.385    0.166
# 3   1985   0.332        1.122  0.394  0.563  0.945  1.161  1.378    0.168
# 4   1986   0.322        1.184  0.383  0.547  0.920  1.155  1.390    0.164
# 5   1987   0.335        1.143  0.392  0.560  0.940  1.160  1.380    0.167
# 6   1988   0.335        1.101  0.399  0.570  0.956  1.164  1.372    0.170
# 7   1989   0.336        1.126  0.398  0.568  0.952  1.163  1.374    0.169
# 8   1990   0.339        1.103  0.402  0.575  0.962  1.165  1.369    0.170
# 9   1991   0.336        1.089  0.403  0.576  0.964  1.166  1.368    0.171
# 10  1992   0.345        1.045  0.413  0.591  0.986  1.171  1.357    0.174
# 11  1993   0.320        1.183  0.383  0.548  0.921  1.155  1.389    0.164
# ...

# %%
df.to_csv('wOBA계산을위한_연도별상수.csv', index= False)
