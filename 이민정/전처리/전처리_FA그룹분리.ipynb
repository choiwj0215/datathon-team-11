# %%
import pandas as pd
pd.reset_option('display.max_row')
pd.set_option('display.max_columns', None)

# %%
df = pd.read_csv('야수_전처리_ver12.csv')

# %%
df = df.drop(['평균홈런기여'], axis = 1)

# %%
df_2016 = df[df['FA년도'] <= 2016]
df_2024 = df[df['FA년도'] >= 2017]

# %%
df_2016 = df_2016 .drop(['타격 WPA','주루 WPA','WPA+','WPA-','WPA','1점 홈런','2점 홈런 ','3점 홈런','만루 홈런','홈런기여점수'],axis = 1)

# %%
df_2016
# Out:
#      FA년도 구단명        선수명 포지션   투   타   구분 FA등급  플레이년도  나이  게임수  타석수   타수  득점  \
# 0    2014  롯데  강민호(2011)   C  우투  우타   신규    A   2010  25  117  465  410  66
# 1    2014  롯데  강민호(2011)   C  우투  우타   신규    A   2011  26  124  506  450  63
# 2    2014  롯데  강민호(2011)   C  우투  우타   신규    A   2012  27  119  454  400  41
# 3    2014  롯데  강민호(2011)   C  우투  우타   신규    A   2013  28  105  405  327  48
# 14   2016  두산  고영민(2013)  2B  우투  우타   신규    A   2012  28   58  173  151  33
# ..    ...  ..        ...  ..  ..  ..  ...  ...    ...  ..  ...  ...  ...  ..
# 491  2014  한화  한상훈(2012)  SS  우투  좌타   신규    A   2013  33  101  322  260  45
# 504  2013  롯데  홍성흔(2010)  DH  우투  우타  재자격    A   2009  32  119  487  426  71
# 505  2013  롯데  홍성흔(2010)  DH  우투  우타  재자격    A   2010  33  111  498  431  88
# 506  2013  롯데  홍성흔(2010)  DH  우투  우타  재자격    A   2011  34  132  535  474  70
# 507  2013  롯데  홍성흔(2010)  DH  우투  우타  재자격    A   2012  35  113  443  390  48
#
# ...

# %%
df_2024
# Out:
#      FA년도 구단명        선수명 포지션   투   타   구분 FA등급  플레이년도  나이  게임수  타석수   타수   득점  \
# 4    2018  롯데  강민호(2015)   C  우투  우타  재자격    A   2015  30  123  456  380   63
# 5    2018  롯데  강민호(2015)   C  우투  우타  재자격    A   2016  31  116  460  381   65
# 6    2018  롯데  강민호(2015)   C  우투  우타  재자격    A   2017  32  130  515  456   62
# 7    2022  삼성  강민호(2019)   C  우투  우타  재자격    C   2019  34  112  393  346   36
# 8    2022  삼성  강민호(2019)   C  우투  우타  재자격    C   2020  35  119  393  355   46
# ..    ...  ..        ...  ..  ..  ..  ...  ...    ...  ..  ...  ...  ...  ...
# 510  2017  롯데  황재균(2014)  3B  우투  우타   신규    A   2015  28  144  596  534   95
# 511  2017  롯데  황재균(2014)  3B  우투  우타   신규    A   2016  29  127  559  498   97
# 512  2022  KT  황재균(2019)  3B  우투  우타  재자격    B   2019  32  124  507  448   78
# 513  2022  KT  황재균(2019)  3B  우투  우타  재자격    B   2020  33  134  600  541  108
# 514  2022  KT  황재균(2019)  3B  우투  우타  재자격    B   2021  34  117  507  453   74
#
# ...

# %%
df_2016.to_csv('2013~2016_FA_4년정보.csv', index = False)
df_2024.to_csv('2017~2024_FA_4년정보.csv', index = False)
