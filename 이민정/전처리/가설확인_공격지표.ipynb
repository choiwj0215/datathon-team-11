# %%
import pandas as pd
import statsmodels.api as sm
import matplotlib.pyplot as plt
from matplotlib import rc
import platform

import warnings
warnings.simplefilter(action='ignore', category=pd.errors.SettingWithCopyWarning)

# 한글 폰트 설정
plt.rc('font', family='Malgun Gothic')

# 마이너스 깨짐 방지
plt.rcParams['axes.unicode_minus'] = False

# %%
df = pd.read_csv('야수_전처리_ver_1년차제거.csv')

# %%
df.columns
# Out:
# Index(['FA년도', '구단명', '선수명', '포지션', '투', '타', '구분', 'FA등급', '플레이년도', '나이',
#        '게임수', '타석수', '타수', '득점', '안타', '2루타', '3루타', '사구', '홈런', '타점', '도루성공',
#        '도루실패', '볼넷', '삼진', '병살타', '희생플라이', '공격WAR', '연봉', '비고', '잔류 여부',
#        'FA 계약 연수', 'FA 계약 총액', 'wRC+', '장타율', '출루율', 'OPS', '득점파크팩터', '홈런파크팩터',
#        '장타파크팩터', '구단지역', '국대출전횟수', '원클럽맨여부', '타격 WPA', '주루 WPA', 'WPA+',
#        'WPA-', 'WPA', '1점 홈런', '2점 홈런 ', '3점 홈런', '만루 홈런', '선수명_수정', '홈런기여점수',
#        '평균홈런기여'],
#       dtype='object')

# %%
df= df[['선수명','게임수', '타석수', '타수', '득점', '안타', '2루타', '3루타', '사구', '홈런', '타점', '도루성공',
       '도루실패', '볼넷', '삼진', '병살타', '희생플라이', '공격WAR', '연봉',
       'FA 계약 연수', 'FA 계약 총액', 'wRC+', '장타율', '출루율', 'OPS', '타격 WPA', '주루 WPA', 'WPA+',
       'WPA-', 'WPA', '1점 홈런', '2점 홈런 ', '3점 홈런', '만루 홈런', '선수명_수정', '홈런기여점수',
       '평균홈런기여']]

# %%
df
# Out:
#            선수명  게임수  타석수   타수   득점   안타  2루타  3루타  사구  홈런  ...   WPA+  WPA-  \
# 0    강민호(2011)  117  465  410   66  125   19    1   8  23  ...    NaN   NaN
# 1    강민호(2011)  124  506  450   63  130   25    2   8  19  ...    NaN   NaN
# 2    강민호(2011)  119  454  400   41  109   21    0   8  19  ...    NaN   NaN
# 3    강민호(2011)  105  405  327   48   77   13    0  11  11  ...   9.13 -6.91
# 4    강민호(2015)  123  456  380   63  118   18    1  14  35  ...  11.08 -6.49
# ..         ...  ...  ...  ...  ...  ...  ...  ...  ..  ..  ...    ...   ...
# 530  황재균(2014)  127  559  498   97  167   26    5   4  27  ...  14.27 -9.75
# 531  황재균(2017)   18   57   52    2    6    1    0   0   1  ...    NaN   NaN
# 532  황재균(2019)  124  507  448   78  127   16    3   2  20  ...  10.99 -8.92
# 533  황재균(2019)  134  600  541  108  169   35    5   5  21  ...  13.38 -9.64
# 534  황재균(2019)  117  507  453   74  132   16    2   3  10  ...   8.61 -9.00
#
# ...

# %% [markdown]
# ### 출전

# %%
# 출전 수
df[['게임수', '타석수', '타수','FA 계약 연수', 'FA 계약 총액']].corr()
# Out:
#                게임수       타석수        타수  FA 계약 연수  FA 계약 총액
# 게임수       1.000000  0.892261  0.893131  0.087470  0.163424
# 타석수       0.892261  1.000000  0.993169  0.113946  0.215406
# 타수        0.893131  0.993169  1.000000  0.105152  0.205185
# FA 계약 연수  0.087470  0.113946  0.105152  1.000000  0.834674
# FA 계약 총액  0.163424  0.215406  0.205185  0.834674  1.000000

# %%
X = df[['게임수']]
X = sm.add_constant(X)
y = df['FA 계약 총액']

model = sm.OLS(y, X).fit()
print(model.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:               FA 계약 총액   R-squared:                       0.027
# Model:                            OLS   Adj. R-squared:                  0.025
# Method:                 Least Squares   F-statistic:                     14.63
# Date:                Tue, 29 Jul 2025   Prob (F-statistic):           0.000147
# Time:                        15:05:49   Log-Likelihood:                -7411.8
# No. Observations:                 535   AIC:                         1.483e+04
# Df Residuals:                     533   BIC:                         1.484e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const      -5.447e+04   4.24e+04     -1.283      0.200   -1.38e+05    2.89e+04
# ...

# %%
X = df[['타석수']]
X = sm.add_constant(X)
y = df['FA 계약 총액']

model = sm.OLS(y, X).fit()
print(model.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:               FA 계약 총액   R-squared:                       0.046
# Model:                            OLS   Adj. R-squared:                  0.045
# Method:                 Least Squares   F-statistic:                     25.93
# Date:                Tue, 29 Jul 2025   Prob (F-statistic):           4.91e-07
# Time:                        15:05:40   Log-Likelihood:                -7406.3
# No. Observations:                 535   AIC:                         1.482e+04
# Df Residuals:                     533   BIC:                         1.483e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const      -4.286e+04   3.05e+04     -1.406      0.160   -1.03e+05     1.7e+04
# ...

# %% [raw]
# 게임수, 타석수 모두 유의미함

# %% [markdown]
# ### 공격

# %%
# 타격지표
df[['득점', '안타', '2루타', '3루타', '사구', '홈런', '타점', 
    '볼넷', '삼진', '병살타', '희생플라이', 'FA 계약 연수', 'FA 계약 총액']].corr()
# Out:
#                 득점        안타       2루타       3루타        사구        홈런  \
# 득점        1.000000  0.916269  0.831378  0.412919  0.390892  0.633542
# 안타        0.916269  1.000000  0.885125  0.342886  0.359359  0.591003
# 2루타       0.831378  0.885125  1.000000  0.232095  0.335425  0.604523
# 3루타       0.412919  0.342886  0.232095  1.000000 -0.012121 -0.038721
# 사구        0.390892  0.359359  0.335425 -0.012121  1.000000  0.471925
# 홈런        0.633542  0.591003  0.604523 -0.038721  0.471925  1.000000
# 타점        0.796046  0.839564  0.815971  0.133690  0.417096  0.861699
# 볼넷        0.745422  0.735494  0.644995  0.229053  0.327542  0.551047
# 삼진        0.608062  0.583482  0.561645  0.123853  0.392566  0.693122
# 병살타       0.448407  0.585423  0.529150  0.008413  0.313866  0.393740
# 희생플라이     0.431992  0.494120  0.484456  0.149324  0.227686  0.329643
# FA 계약 연수  0.103264  0.096710  0.099931 -0.013124  0.065083  0.054188
# FA 계약 총액  0.208929  0.198746  0.203696 -0.010889  0.174688  0.177554
#
# ...

# %%
# 공격
X = df[['득점', '안타', '2루타', '3루타', '홈런', '타점', 
    '병살타', '희생플라이']]
X = sm.add_constant(X)
y = df['FA 계약 총액']

model = sm.OLS(y, X).fit()
print(model.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:               FA 계약 총액   R-squared:                       0.059
# Model:                            OLS   Adj. R-squared:                  0.045
# Method:                 Least Squares   F-statistic:                     4.122
# Date:                Tue, 29 Jul 2025   Prob (F-statistic):           8.69e-05
# Time:                        14:14:25   Log-Likelihood:                -7402.8
# No. Observations:                 535   AIC:                         1.482e+04
# Df Residuals:                     526   BIC:                         1.486e+04
# Df Model:                           8
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const      -1.262e+04   2.76e+04     -0.457      0.648   -6.68e+04    4.16e+04
# ...

# %%
X = df[['득점']]
X = sm.add_constant(X)
y = df['FA 계약 총액']

model = sm.OLS(y, X).fit()
print(model.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:               FA 계약 총액   R-squared:                       0.044
# Model:                            OLS   Adj. R-squared:                  0.042
# Method:                 Least Squares   F-statistic:                     24.33
# Date:                Tue, 29 Jul 2025   Prob (F-statistic):           1.09e-06
# Time:                        15:07:45   Log-Likelihood:                -7407.1
# No. Observations:                 535   AIC:                         1.482e+04
# Df Residuals:                     533   BIC:                         1.483e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const      -5579.0508   2.44e+04     -0.229      0.819   -5.35e+04    4.24e+04
# ...

# %%
X = df[['안타']]
X = sm.add_constant(X)
y = df['FA 계약 총액']

model = sm.OLS(y, X).fit()
print(model.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:               FA 계약 총액   R-squared:                       0.040
# Model:                            OLS   Adj. R-squared:                  0.038
# Method:                 Least Squares   F-statistic:                     21.92
# Date:                Tue, 29 Jul 2025   Prob (F-statistic):           3.61e-06
# Time:                        15:08:01   Log-Likelihood:                -7408.3
# No. Observations:                 535   AIC:                         1.482e+04
# Df Residuals:                     533   BIC:                         1.483e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const      -1.242e+04   2.68e+04     -0.463      0.643   -6.51e+04    4.02e+04
# ...

# %%
X = df[['2루타']]
X = sm.add_constant(X)
y = df['FA 계약 총액']

model = sm.OLS(y, X).fit()
print(model.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:               FA 계약 총액   R-squared:                       0.041
# Model:                            OLS   Adj. R-squared:                  0.040
# Method:                 Least Squares   F-statistic:                     23.07
# Date:                Tue, 29 Jul 2025   Prob (F-statistic):           2.03e-06
# Time:                        15:08:09   Log-Likelihood:                -7407.7
# No. Observations:                 535   AIC:                         1.482e+04
# Df Residuals:                     533   BIC:                         1.483e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       3047.7796   2.33e+04      0.131      0.896   -4.28e+04    4.89e+04
# ...

# %%
X = df[['3루타']]
X = sm.add_constant(X)
y = df['FA 계약 총액']

model = sm.OLS(y, X).fit()
print(model.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:               FA 계약 총액   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                 -0.002
# Method:                 Least Squares   F-statistic:                   0.06321
# Date:                Tue, 29 Jul 2025   Prob (F-statistic):              0.802
# Time:                        15:08:15   Log-Likelihood:                -7419.0
# No. Observations:                 535   AIC:                         1.484e+04
# Df Residuals:                     533   BIC:                         1.485e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       1.045e+05   1.38e+04      7.570      0.000    7.74e+04    1.32e+05
# ...

# %%
X = df[['홈런']]
X = sm.add_constant(X)
y = df['FA 계약 총액']

model = sm.OLS(y, X).fit()
print(model.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:               FA 계약 총액   R-squared:                       0.032
# Model:                            OLS   Adj. R-squared:                  0.030
# Method:                 Least Squares   F-statistic:                     17.35
# Date:                Tue, 29 Jul 2025   Prob (F-statistic):           3.63e-05
# Time:                        15:08:22   Log-Likelihood:                -7410.5
# No. Observations:                 535   AIC:                         1.482e+04
# Df Residuals:                     533   BIC:                         1.483e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       4.964e+04   1.67e+04      2.975      0.003    1.69e+04    8.24e+04
# ...

# %%
X = df[['타점']]
X = sm.add_constant(X)
y = df['FA 계약 총액']

model = sm.OLS(y, X).fit()
print(model.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:               FA 계약 총액   R-squared:                       0.045
# Model:                            OLS   Adj. R-squared:                  0.043
# Method:                 Least Squares   F-statistic:                     25.23
# Date:                Tue, 29 Jul 2025   Prob (F-statistic):           6.94e-07
# Time:                        15:08:31   Log-Likelihood:                -7406.7
# No. Observations:                 535   AIC:                         1.482e+04
# Df Residuals:                     533   BIC:                         1.483e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       2827.2888   2.26e+04      0.125      0.900   -4.15e+04    4.72e+04
# ...

# %%
X = df[['병살타']]
X = sm.add_constant(X)
y = df['FA 계약 총액']

model = sm.OLS(y, X).fit()
print(model.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:               FA 계약 총액   R-squared:                       0.018
# Model:                            OLS   Adj. R-squared:                  0.017
# Method:                 Least Squares   F-statistic:                     10.04
# Date:                Tue, 29 Jul 2025   Prob (F-statistic):            0.00162
# Time:                        15:08:44   Log-Likelihood:                -7414.1
# No. Observations:                 535   AIC:                         1.483e+04
# Df Residuals:                     533   BIC:                         1.484e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       4.133e+04   2.22e+04      1.865      0.063   -2204.960    8.49e+04
# ...

# %%
X = df[['희생플라이']]
X = sm.add_constant(X)
y = df['FA 계약 총액']

model = sm.OLS(y, X).fit()
print(model.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:               FA 계약 총액   R-squared:                       0.016
# Model:                            OLS   Adj. R-squared:                  0.015
# Method:                 Least Squares   F-statistic:                     8.911
# Date:                Tue, 29 Jul 2025   Prob (F-statistic):            0.00296
# Time:                        15:08:48   Log-Likelihood:                -7414.6
# No. Observations:                 535   AIC:                         1.483e+04
# Df Residuals:                     533   BIC:                         1.484e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        6.02e+04   1.79e+04      3.367      0.001    2.51e+04    9.53e+04
# ...

# %%
X = df[['사구']]
X = sm.add_constant(X)
y = df['FA 계약 총액']

model = sm.OLS(y, X).fit()
print(model.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:               FA 계약 총액   R-squared:                       0.031
# Model:                            OLS   Adj. R-squared:                  0.029
# Method:                 Least Squares   F-statistic:                     16.78
# Date:                Tue, 29 Jul 2025   Prob (F-statistic):           4.86e-05
# Time:                        15:11:41   Log-Likelihood:                -7410.8
# No. Observations:                 535   AIC:                         1.483e+04
# Df Residuals:                     533   BIC:                         1.483e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       4.954e+04   1.69e+04      2.936      0.003    1.64e+04    8.27e+04
# ...

# %%
X = df[['볼넷']]
X = sm.add_constant(X)
y = df['FA 계약 총액']

model = sm.OLS(y, X).fit()
print(model.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:               FA 계약 총액   R-squared:                       0.056
# Model:                            OLS   Adj. R-squared:                  0.055
# Method:                 Least Squares   F-statistic:                     31.80
# Date:                Tue, 29 Jul 2025   Prob (F-statistic):           2.78e-08
# Time:                        15:11:44   Log-Likelihood:                -7403.6
# No. Observations:                 535   AIC:                         1.481e+04
# Df Residuals:                     533   BIC:                         1.482e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const      -1.622e+04   2.36e+04     -0.687      0.492   -6.26e+04    3.02e+04
# ...

# %% [raw]
# 3루타는 유의미하지 않음

# %% [markdown]
# ### 타격지표 확장

# %%
# 타격지표 확장
df[['공격WAR','wRC+', '장타율', '출루율', 'OPS','홈런기여점수','평균홈런기여','FA 계약 연수', 'FA 계약 총액']].corr()
# Out:
#              공격WAR      wRC+       장타율       출루율       OPS    홈런기여점수  \
# 공격WAR     1.000000  0.824106  0.682889  0.754774  0.750868  0.684778
# wRC+      0.824106  1.000000  0.799860  0.866442  0.874454  0.619934
# 장타율       0.682889  0.799860  1.000000  0.678755  0.977772  0.775990
# 출루율       0.754774  0.866442  0.678755  1.000000  0.817642  0.451853
# OPS       0.750868  0.874454  0.977772  0.817642  1.000000  0.738969
# 홈런기여점수    0.684778  0.619934  0.775990  0.451853  0.738969  1.000000
# 평균홈런기여    0.081407  0.139999  0.079725  0.086553  0.087519  0.216359
# FA 계약 연수  0.107255  0.099353  0.039240  0.087336  0.055699  0.019025
# FA 계약 총액  0.237227  0.193418  0.134142  0.150697  0.148190  0.160420
#
#             평균홈런기여  FA 계약 연수  FA 계약 총액
# 공격WAR     0.081407  0.107255  0.237227
# wRC+      0.139999  0.099353  0.193418
# 장타율       0.079725  0.039240  0.134142
# 출루율       0.086553  0.087336  0.150697
# OPS       0.087519  0.055699  0.148190
# ...

# %%
X = df[['공격WAR']]
X = sm.add_constant(X)
y = df['FA 계약 총액']

model = sm.OLS(y, X).fit()
print(model.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:               FA 계약 총액   R-squared:                       0.056
# Model:                            OLS   Adj. R-squared:                  0.055
# Method:                 Least Squares   F-statistic:                     31.78
# Date:                Tue, 29 Jul 2025   Prob (F-statistic):           2.80e-08
# Time:                        15:12:33   Log-Likelihood:                -7403.6
# No. Observations:                 535   AIC:                         1.481e+04
# Df Residuals:                     533   BIC:                         1.482e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       3.008e+04   1.67e+04      1.799      0.073   -2761.005    6.29e+04
# ...

# %%
X = df[['OPS']]
X = sm.add_constant(X)
y = df['FA 계약 총액']

model = sm.OLS(y, X).fit()
print(model.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:               FA 계약 총액   R-squared:                       0.022
# Model:                            OLS   Adj. R-squared:                  0.020
# Method:                 Least Squares   F-statistic:                     11.97
# Date:                Tue, 29 Jul 2025   Prob (F-statistic):           0.000585
# Time:                        15:12:34   Log-Likelihood:                -7413.1
# No. Observations:                 535   AIC:                         1.483e+04
# Df Residuals:                     533   BIC:                         1.484e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const      -1.107e+05   6.26e+04     -1.769      0.077   -2.34e+05    1.22e+04
# ...

# %%
X = df[['홈런']]
X = sm.add_constant(X)
y = df['FA 계약 총액']

model = sm.OLS(y, X).fit()
print(model.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:               FA 계약 총액   R-squared:                       0.032
# Model:                            OLS   Adj. R-squared:                  0.030
# Method:                 Least Squares   F-statistic:                     17.35
# Date:                Tue, 29 Jul 2025   Prob (F-statistic):           3.63e-05
# Time:                        15:12:35   Log-Likelihood:                -7410.5
# No. Observations:                 535   AIC:                         1.482e+04
# Df Residuals:                     533   BIC:                         1.483e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       4.964e+04   1.67e+04      2.975      0.003    1.69e+04    8.24e+04
# ...

# %%
X = df[['wRC+']]
X = sm.add_constant(X)
y = df['FA 계약 총액']

model = sm.OLS(y, X).fit()
print(model.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:               FA 계약 총액   R-squared:                       0.037
# Model:                            OLS   Adj. R-squared:                  0.036
# Method:                 Least Squares   F-statistic:                     20.71
# Date:                Tue, 29 Jul 2025   Prob (F-statistic):           6.61e-06
# Time:                        15:12:48   Log-Likelihood:                -7408.9
# No. Observations:                 535   AIC:                         1.482e+04
# Df Residuals:                     533   BIC:                         1.483e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       -5.58e+04   3.64e+04     -1.533      0.126   -1.27e+05    1.57e+04
# ...

# %%
X = df[['장타율']]
X = sm.add_constant(X)
y = df['FA 계약 총액']

model = sm.OLS(y, X).fit()
print(model.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:               FA 계약 총액   R-squared:                       0.018
# Model:                            OLS   Adj. R-squared:                  0.016
# Method:                 Least Squares   F-statistic:                     9.767
# Date:                Tue, 29 Jul 2025   Prob (F-statistic):            0.00187
# Time:                        15:13:12   Log-Likelihood:                -7414.2
# No. Observations:                 535   AIC:                         1.483e+04
# Df Residuals:                     533   BIC:                         1.484e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const      -4.127e+04   4.73e+04     -0.873      0.383   -1.34e+05    5.16e+04
# ...

# %%
X = df[['출루율']]
X = sm.add_constant(X)
y = df['FA 계약 총액']

model = sm.OLS(y, X).fit()
print(model.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:               FA 계약 총액   R-squared:                       0.023
# Model:                            OLS   Adj. R-squared:                  0.021
# Method:                 Least Squares   F-statistic:                     12.39
# Date:                Tue, 29 Jul 2025   Prob (F-statistic):           0.000470
# Time:                        15:13:15   Log-Likelihood:                -7412.9
# No. Observations:                 535   AIC:                         1.483e+04
# Df Residuals:                     533   BIC:                         1.484e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const      -2.134e+05   9.04e+04     -2.361      0.019   -3.91e+05   -3.58e+04
# ...
