# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import gc
import glob

# 그래프 기본 테마 설정
# https://coldbrown.co.kr/2023/07/%ED%8C%8C%EC%9D%B4%EC%8D%AC-%EC%8B%A4%EC%A0%84%ED%8E%B8-08-seaborn-sns-set%EC%9D%84-%ED%86%B5%ED%95%B4-%EC%8A%A4%ED%83%80%EC%9D%BC-%EC%84%A4%EC%A0%95%ED%95%98%EA%B8%B0/
sns.set()

# 그래프 기본 설정
plt.rcParams['font.family'] = 'Malgun Gothic'
# plt.rcParams['font.family'] = 'AppleGothic'
plt.rcParams['figure.figsize'] = 12, 6
plt.rcParams['font.size'] = 14
plt.rcParams['axes.unicode_minus'] = False


# 복잡한 통계 처리를 위한 라이브러리
from scipy import stats

# %%
# data_type = "train"
# month = "07"
# category = "잔액정보"

# local
root_path = '../../data'

# colab
# root_path = '/content/drive/MyDrive/12조 파이널프로젝트/data'

#drive_folder = f'{root_path}/스탯티즈_Raw_data/'

# %%
df1 = pd.read_excel(f'{root_path}/2025_롯데_투수.xlsx')

# %% [markdown]
# ## 사사구 (볼넷 + 사구)

# %%
df1['사사구'] = df1['볼넷허용'] + df1['사구허용']

# %%
df1['사사구']
# Out:
# 0     16
# 1     27
# 2     25
# 3     43
# 4     50
# 5     36
# 6     23
# 7     10
# 8     22
# 9     14
# 10     3
# 11     1
# 12    20
# 13    10
# 14     3
# 15    11
# 16     5
# 17     2
# 18     9
# 19     4
# 20    21
# 21    22
# Name: 사사구, dtype: int64

# %%
df1.to_csv('../../data/2025_롯데_투수.csv', index=False, encoding='utf-8-sig')

# %%
df2 = pd.read_csv(f'{root_path}/2025_롯데_투수.csv')
df2
# Out:
#    구단명  선수명 세부포지션   투  플레이년도  나이  게임수  선발등판  구원등판  승리  ...   선발이닝  구원이닝  \
# 0   롯데  김진욱    RP  좌투   2025  23   13     6     7   1  ...   21.2   5.1
# 1   롯데  감보아    SP  좌투   2025  28   11    11     0   7  ...   67.1   0.0
# 2   롯데  김원중    CP  우투   2025  32   41     0    41   3  ...    0.0  43.2
# 3   롯데  나균안    SP  우투   2025  27   21    19     2   2  ...  100.2   2.2
# 4   롯데  박세웅    SP  우투   2025  30   20    20     0  11  ...  115.1   0.0
# 5   롯데  이민석    SP  우투   2025  22   13    13     0   2  ...   66.2   0.0
# 6   롯데  정철원    RP  우투   2025  26   56     0    56   6  ...    0.0  51.2
# 7   롯데  홍민기    RP  좌투   2025  24   20     2    18   0  ...    9.0  20.0
# 8   롯데  정현수    RP  좌투   2025  24   59     0    59   2  ...    0.0  36.2
# 9   롯데  최준용    RP  우투   2025  24   32     0    32   3  ...    0.0  34.0
# 10  롯데  한현희    RP  우투   2025  32    3     2     1   0  ...    8.1   0.1
# 11  롯데  정우준    RP  우투   2025  25    2     0     2   0  ...    0.0   1.1
# ...
